# %%
from tensorflow import keras

(x_train, y_train), (x_test, y_test) = keras.datasets.imdb.load_data(num_words=20000)
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=80)
x_test = keras.preprocessing.sequence.pad_sequences(x_test, maxlen=80)

model = keras.models.Sequential()
model.add(keras.layers.Embedding(20000, 32))
model.add(keras.layers.LSTM(32))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(x_train, y_train, validation_data=(x_test, y_test),
        batch_size=32,
        epochs=5)
_, accuracy = model.evaluate(x_test, y_test, batch_size=32)
print('Test accuracy:', accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# WARNING: Logging before flag parsing goes to stderr.
# W0709 08:40:46.935915 140691204917120 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0709 08:40:46.973898 140691204917120 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0709 08:40:47.266056 140691204917120 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/5
# 25000/25000 [==============================] - 140s 6ms/sample - loss: 0.4272 - acc: 0.7966 - val_loss: 0.3862 - val_acc: 0.8292
# Epoch 2/5
# 25000/25000 [==============================] - 137s 5ms/sample - loss: 0.2577 - acc: 0.8996 - val_loss: 0.3818 - val_acc: 0.8319
# Epoch 3/5
# 25000/25000 [==============================] - 137s 5ms/sample - loss: 0.1840 - acc: 0.9310 - val_loss: 0.4066 - val_acc: 0.8290
# Epoch 4/5
# 25000/25000 [==============================] - 137s 5ms/sample - loss: 0.1239 - acc: 0.9555 - val_loss: 0.5514 - val_acc: 0.8205
# Epoch 5/5
# 25000/25000 [==============================] - 138s 6ms/sample - loss: 0.0833 - acc: 0.9704 - val_loss: 0.5631 - val_acc: 0.8138
#  6304/25000 [======>.......................] - ETA: 18s - loss: 0.5857 - acc: 0.8082
